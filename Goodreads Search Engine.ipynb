# %% [markdown]
# # Book Search Engine
# This search engine will search a large book dataset scraped from the goodreads website by using their developer API (dataset from https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks) and display all of its information. The information we can collect from this dataset is the book ID, title, author, average rating, language, number of pages, number of ratings, number of text reviews, publication date, and publisher.

# %%
#import packages
import pandas as pd
import numpy as np
import seaborn as sns
import re
import sklearn

# %% [markdown]
# # Importing Data

# %%
#open csv file
book_data = pd.read_csv("/Users/intisarmuhammad/Downloads/books.csv")

# %%
#view data of first 5 rows
book_data.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating language_code  num_pages  \
# 0  J.K. Rowling/Mary GrandPré            4.57           eng        652
# 1  J.K. Rowling/Mary GrandPré            4.49           eng        870
# 2                J.K. Rowling            4.42           eng        352
# 3  J.K. Rowling/Mary GrandPré            4.56           eng        435
# 4  J.K. Rowling/Mary GrandPré            4.78           eng       2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591          9/16/06  Scholastic Inc.
# 1        2153167               29221           9/1/04  Scholastic Inc.
# 2           6333                 244          11/1/03       Scholastic
# 3        2339585               36325           5/1/04  Scholastic Inc.
# 4          41428                 164          9/13/04       Scholastic

# %%
book_data.shape
# Out:
# (11123, 10)

# %% [markdown]
# # Data Cleaning

# %%
# create new title column for modified title names (remove non alphanumeric characters)
# this will make search queries easier for our search engine
book_data["mod_title"] = book_data["title"].str.replace("[^a-zA-Z0-9 ]", "", regex = True)

# %%
book_data
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#       language_code  num_pages  ratings_count  text_reviews_count  \
# 0               eng        652        2095690               27591
# 1               eng        870        2153167               29221
# 2               eng        352           6333                 244
# 3               eng        435        2339585               36325
# 4               eng       2690          41428                 164
# ...             ...        ...            ...                 ...
# 11118           eng        512            156                  20
# 11119           eng        635            783                  56
# 11120           eng        415            820                  95
# 11121           eng        434            769                 139
# 11122           spa        272            113                  12
#
#       publication_date        publisher  \
# 0              9/16/06  Scholastic Inc.
# 1               9/1/04  Scholastic Inc.
# 2              11/1/03       Scholastic
# 3               5/1/04  Scholastic Inc.
# 4              9/13/04       Scholastic
# ...                ...              ...
# 11118         12/21/04    Da Capo Press
# 11119          12/1/88    Penguin Books
# 11120           8/1/93    Penguin Books
# 11121          2/27/07             Ecco
# 11122          5/28/06    Edimat Libros
#
#                                                mod_title
# 0      Harry Potter and the HalfBlood Prince Harry Po...
# 1      Harry Potter and the Order of the Phoenix Harr...
# 2      Harry Potter and the Chamber of Secrets Harry ...
# 3      Harry Potter and the Prisoner of Azkaban Harry...
# 4      Harry Potter Boxed Set  Books 15 Harry Potter  15
# ...                                                  ...
# 11118     Expelled from Eden A William T Vollmann Reader
# 11119                        You Bright and Risen Angels
# 11120                        The IceShirt Seven Dreams 1
# 11121                                        Poor People
# 11122                        Las aventuras de Tom Sawyer
#
# [11123 rows x 11 columns]

# %%
# transform modified titles to lower case
book_data["mod_title"] = book_data["mod_title"].str.lower()

# %%
# remove multiple spaces in a row
book_data["mod_title"] = book_data["mod_title"].str.replace("\s+", " ", regex = True)

# %%
#view the data
book_data
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#       language_code  num_pages  ratings_count  text_reviews_count  \
# 0               eng        652        2095690               27591
# 1               eng        870        2153167               29221
# 2               eng        352           6333                 244
# 3               eng        435        2339585               36325
# 4               eng       2690          41428                 164
# ...             ...        ...            ...                 ...
# 11118           eng        512            156                  20
# 11119           eng        635            783                  56
# 11120           eng        415            820                  95
# 11121           eng        434            769                 139
# 11122           spa        272            113                  12
#
#       publication_date        publisher  \
# 0              9/16/06  Scholastic Inc.
# 1               9/1/04  Scholastic Inc.
# 2              11/1/03       Scholastic
# 3               5/1/04  Scholastic Inc.
# 4              9/13/04       Scholastic
# ...                ...              ...
# 11118         12/21/04    Da Capo Press
# 11119          12/1/88    Penguin Books
# 11120           8/1/93    Penguin Books
# 11121          2/27/07             Ecco
# 11122          5/28/06    Edimat Libros
#
#                                                mod_title
# 0      harry potter and the halfblood prince harry po...
# 1      harry potter and the order of the phoenix harr...
# 2      harry potter and the chamber of secrets harry ...
# 3      harry potter and the prisoner of azkaban harry...
# 4        harry potter boxed set books 15 harry potter 15
# ...                                                  ...
# 11118     expelled from eden a william t vollmann reader
# 11119                        you bright and risen angels
# 11120                        the iceshirt seven dreams 1
# 11121                                        poor people
# 11122                        las aventuras de tom sawyer
#
# [11120 rows x 11 columns]

# %%
# remove null titles
book_data = book_data[book_data["mod_title"].str.len() > 0]

# %%
book_data.shape
# the above process removed 3 books
# Out:
# (11120, 11)

# %% [markdown]
# # Building the search engine
# This search engine will match the title of a book you input and also find books with similar titles to display.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(book_data["mod_title"])

# %%
# turn search query into vector and match it against the tfidf matrix and then compare (using a function)
from sklearn.metrics.pairwise import cosine_similarity

def search(query, vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten()

    # find the 10 largest similarities
    indices = np.argpartition(similarity, -10)[-10:]

    # index the titles
    results = book_data.iloc[indices]

    # sort results on the highest number of ratings
    results = results.sort_values("ratings_count", ascending = False)
    return results.head(5)

# %%
# run the function with a book title
search("the alchemist", vectorizer)
# Out:
#       bookID                                              title  \
# 284      865                                      The Alchemist
# 288      870  Fullmetal Alchemist  Vol. 1 (Fullmetal Alchemi...
# 287      869  Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemi...
# 285      866  Fullmetal Alchemist  Vol. 9 (Fullmetal Alchemi...
# 6978   26425  Fullmetal Alchemist: The Abducted Alchemist (F...
#
#                                                 authors  average_rating  \
# 284            Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86
# 288                       Hiromu Arakawa/Akira Watanabe            4.50
# 287                       Hiromu Arakawa/Akira Watanabe            4.57
# 285                       Hiromu Arakawa/Akira Watanabe            4.57
# 6978  Makoto Inoue/Hiromu Arakawa/Alexander O. Smith...            4.57
#
#      language_code  num_pages  ratings_count  text_reviews_count  \
# 284            eng        197        1631221               55843
# 288            eng        192         111091                1427
# 287            eng        192          11451                 161
# 285            eng        192           9013                 153
# 6978           eng        240           2779                  19
#
#      publication_date      publisher  \
# 284            5/1/93  HarperCollins
# 288            5/3/05  VIZ Media LLC
# 287           7/18/06  VIZ Media LLC
# 285           9/19/06  VIZ Media LLC
# 6978          1/10/06  VIZ Media LLC
#
#                                               mod_title
# 284                                       the alchemist
# 288     fullmetal alchemist vol 1 fullmetal alchemist 1
# 287     fullmetal alchemist vol 8 fullmetal alchemist 8
# 285     fullmetal alchemist vol 9 fullmetal alchemist 9
# 6978  fullmetal alchemist the abducted alchemist ful...

# %% [markdown]
# # Creating a list of liked books
# In this section, I will be using my search engine from above to query the books that I read (titles from my personal Goodreads account; https://www.goodreads.com/user/show/50112085-star) and create a list of their book ids if the query exists in the data.

# %%
# book ids of 7 of the books I like
liked_books = ["37415", "10210", "27451", "7613", "3636", "22188","865"]

# %%
# Display the rows of books from my liked books list by their book ID
book_data.loc[book_data["bookID"].isin(["37415", "10210", "27451", "7613", "3636", "22188","865"])]
# Out:
#       bookID                          title  \
# 284      865                  The Alchemist
# 1069    3636      The Giver (The Giver  #1)
# 2114    7613                    Animal Farm
# 2764   10210                      Jane Eyre
# 5887   22188  Gossip Girl (Gossip Girl  #1)
# 7161   27451               The Great Gatsby
# 9427   37415   Their Eyes Were Watching God
#
#                                        authors  average_rating language_code  \
# 284   Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86           eng
# 1069                                Lois Lowry            4.13           eng
# 2114   George Orwell/Boris Grabnar/Peter Škerl            3.93           eng
# 2764            Charlotte Brontë/Michael Mason            4.12           eng
# 5887                       Cecily von Ziegesar            3.52           eng
# 7161   F. Scott Fitzgerald/Matthew J. Bruccoli            3.91           eng
# 9427                        Zora Neale Hurston            3.91           eng
#
#       num_pages  ratings_count  text_reviews_count publication_date  \
# 284         197        1631221               55843           5/1/93
# 1069        208        1585589               56604          1/24/06
# 2114        122        2111750               29677           5/6/03
# 2764        532        1409369               27884           2/4/03
# 5887        224          54400                2271           4/1/02
# 7161        216           9844                1050           6/1/95
# 9427        219         220309                9536          5/30/06
#
#                       publisher                     mod_title
# 284               HarperCollins                 the alchemist
# 1069                      Ember         the giver the giver 1
# 2114                        NAL                   animal farm
# 2764                    Penguin                     jane eyre
# 5887  Little  Brown and Company     gossip girl gossip girl 1
# 7161                   Scribner              the great gatsby
# 9427                    Amistad  their eyes were watching god
